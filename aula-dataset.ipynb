# %% [markdown]
# ## Importações de Biblioteca

# %%
# Importa todas as bibliotecas necessárias
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
lista = pd.Series([74.6,75,83.4,57.6], 
                  index=['Albania',
                         'Nigeria',
                         'Angola',
                         'Andorra'])
# Mostra toda a séria
lista

# Mostra a posição [1]
#lista[1]
# Mostra a posição [1]
#lista.iloc[1]

# Mostra a posição correspondente ao indice ['Angola']
#lista['Angola']
# Mostra a posição correspondente ao indice ['Angola']
#lista.loc['Angola']
#lista.min()
lista.plot(title='Taxa de Vida',legend=True,
           label='anos')

# %%
lista = pd.Series([74.6,75,83.4,57.6])
# Mostra toda a séria
lista
lista[1]
lista.loc[1]
lista.iloc[1]
# Out:
# 75.0

# %%
data_frame = pd.DataFrame(
                {'matricula': [100, 200, 300, 400], 
                 'status'   : ['ativa', 'ativa', 'ativa', 'cancelada'], 
                 'idade'    : [25, 30, 27, 34]})
data_frame
# Out:
#    idade  matricula     status
# 0     25        100      ativa
# 1     30        200      ativa
# 2     27        300      ativa
# 3     34        400  cancelada

# %%
# Leitura de Arquivos - '201508_trip_data.csv'
sample_data       = pd.read_csv('201508_trip_data.csv')

# %%
sample_data.head()
# Out:
#    Trip ID  Duration       Start Date                         Start Station  \
# 0   913460       765  8/31/2015 23:26  Harry Bridges Plaza (Ferry Building)
# 1   913459      1036  8/31/2015 23:11           San Antonio Shopping Center
# 2   913455       307  8/31/2015 23:13                        Post at Kearny
# 3   913454       409  8/31/2015 23:10                    San Jose City Hall
# 4   913453       789  8/31/2015 23:09                 Embarcadero at Folsom
#
#    Start Terminal         End Date                               End Station  \
# 0              50  8/31/2015 23:39  San Francisco Caltrain (Townsend at 4th)
# 1              31  8/31/2015 23:28                   Mountain View City Hall
# 2              47  8/31/2015 23:18                         2nd at South Park
# 3              10  8/31/2015 23:17                       San Salvador at 1st
# 4              51  8/31/2015 23:22                    Embarcadero at Sansome
#
# ...

# %%
new_sample_order = sample_data.groupby('Start Terminal').count()

# %%
new_sample_order
# Out:
#                 Trip ID  Duration  Start Date  Start Station  End Date  \
# Start Terminal
# 2                  4968      4968        4968           4968      4968
# 3                   774       774         774            774       774
# 4                  1958      1958        1958           1958      1958
# 5                   562       562         562            562       562
# 6                  1418      1418        1418           1418      1418
# 7                   856       856         856            856       856
# 8                   495       495         495            495       495
# 9                   885       885         885            885       885
# 10                  832       832         832            832       832
# 11                 1099      1099        1099           1099      1099
# 12                  475       475         475            475       475
# 13                  839       839         839            839       839
# ...

# %%
# Realiza o agrupamento e contagem
new_sample_order = sample_data.groupby('Subscriber Type').count()
# Mostra o agrupamento das viagens (Trip ID) por terminal (Start Terminal) 
new_sample_order['Trip ID']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-05c9a5698b94> in <module>()
#       1 # Realiza o agrupamento e contagem
# ----> 2 new_sample_order = sample_data.groupby('Subscriber Type').count()
#       3 # Mostra o agrupamento das viagens (Trip ID) por terminal (Start Terminal)
#       4 new_sample_order['Trip ID']
#
# NameError: name 'sample_data' is not defined

# %%
sample_data['Subscriber Type'].value_counts().plot(kind='pie', title='Suscriber x Customer', legend=True, table=True)

# %%
new_sample_data = sample_data[(sample_data['Duration'] < 70)] 
new_sample_data['Duration'].value_counts().plot(kind='bar')

# %%
new_sample_data = sample_data[sample_data['Start Terminal'] == 51].groupby('Subscriber Type').count()
new_sample_data['Trip ID']
# Out:
# Subscriber Type
# Customer       792
# Subscriber    6804
# Name: Trip ID, dtype: int64
